# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly as py
import plotly.graph_objs as go
import plotly.io as pio
from datetime import datetime
from datetime import timedelta


#py.offline.init_notebook_mode(connected=True)
pio.renderers.default = "notebook"
#pio.renderers

# %%
def get_dataframe(signal, file_path, column_names):
    
    def get_sample_time(index, init_time, Ts):
        aux = []
        for i in index:
            aux.append((init_time + timedelta(seconds=Ts*i)).strftime("%H:%M:%S:%f"))

        return aux

    df = pd.read_csv(file_path, names=column_names, header=None)
    timestamp = df.iloc[0, :][0]
    
    if signal in ('acc', 'eda', 'hr', 'temp', 'bvp'):
        initial_time = datetime.utcfromtimestamp(timestamp)
        fs = df.iloc[1, :][0]
        Ts = 1/fs
        df = df.drop([0, 1]).reset_index(drop=True).reset_index()
        df.loc[:, 'time'] = get_sample_time(df['index'], initial_time, Ts)
    else:
        df = df.drop([0, 1]).reset_index(drop=True).reset_index()
        df['time'] = df.apply(lambda x : 
                              (datetime.utcfromtimestamp(x['diff'] + timestamp).strftime("%H:%M:%S:%f")), axis=1)
    return df

# %%
path_to_acc = "datos E4/P1-530412/1/ACC.csv"
path_to_eda = "datos E4/P1-530412/1/EDA.csv"
path_to_bvp = "datos E4/P1-530412/1/BVP.csv"
path_to_temp = "datos E4/P1-530412/1/TEMP.csv"
path_to_hr = "datos E4/P1-530412/1/HR.csv"
path_to_ibi = "datos E4/P1-530412/1/IBI.csv"

acc_col_name = ['x', 'y', 'z']
eda_col_name = ['EDA'] 
bvp_col_name = ['BVP']
temp_col_name = ['TEMP']
hr_col_name = ['HR']
ibi_col_name = ['diff', 'IBI']

# %%
acc_df = get_dataframe(
     signal='acc',
     file_path=path_to_acc,
     column_names=acc_col_name)

eda_df = get_dataframe(
     signal='eda',
     file_path=path_to_eda,
     column_names=eda_col_name)

bvp_df = get_dataframe(
     signal='bvp',
     file_path=path_to_bvp,
     column_names=bvp_col_name)

temp_df = get_dataframe(
     signal='temp',
     file_path=path_to_temp,
     column_names=temp_col_name)

hr_df = get_dataframe(
     signal='hr',
     file_path=path_to_hr,
     column_names=hr_col_name)
    
    
ibi_df = get_dataframe(
    signal='ibi',
    file_path=path_to_ibi,
    column_names=ibi_cola_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-6419bb1885f8> in <module>
#      28     signal='ibi',
#      29     file_path=path_to_ibi,
# ---> 30     column_names=ibi_cola_name)
#
# NameError: name 'ibi_cola_name' is not defined

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
                x=acc_df['index'],
                y=acc_df['x'],
                mode='lines',
                name='X-axis'))
fig.add_trace(go.Scatter(
                x=acc_df['index'],
                y=acc_df['y'],
                mode='lines',
                name='Y-axis'))
fig.add_trace(go.Scatter(
                x=acc_df['index'],
                y=acc_df['z'],
                mode='lines',
                name='Z-axis'))

fig.update_layout(title='Acc data measured for patien 1')

fig.show()

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=temp_df['time'],
    y=temp_df['TEMP'],
    mode='lines',
    name='Temperature'))

fig.update_layout(title='Temperature meassured for patient 1')

fig.show()

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=bvp_df['time'],
    y=bvp_df['BVP'],
    mode='lines',
    name='BVP'))

fig.update_layout(title='BVP meassured for patient 1')

fig.show()

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=eda_df['time'],
    y=eda_df['EDA'],
    mode='lines',
    name='EDA'))

fig.update_layout(title='EDA meassured for patient 1')

fig.show()

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=hr_df['time'],
    y=hr_df['HR'],
    mode='lines',
    name='HR'))

fig.update_layout(title='HR meassured for patient 1')

fig.show()

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=ibi_df['time'],
    y=ibi_df['IBI'],
    mode='lines',
    name='IBI'))

fig.update_layout(title='IBI meassured for patient 1')

fig.show()

# %%
path_to_ibi = "datos E4/P1-530412/1/IBI.csv"
column_names = ['diff', 'IBI']
df = pd.read_csv(path_to_ibi, names=column_names, header=None)
timestamp = df.iloc[0 , :][0]
initial_time = datetime.utcfromtimestamp(timestamp)
df = df.drop([0, 1]).reset_index(drop=True).reset_index()
diff = df['diff'][1]
#print(initial_time)
#print(datetime.utcfromtimestamp(diff+timestamp))
df['time'] = df.apply(lambda x : (datetime.utcfromtimestamp(x['diff'] + timestamp).strftime("%H:%M:%S:%f")), axis=1)
df
# Out:
#       index          diff       IBI             time
# 0         0    581.182853  0.875040  05:34:25:182853
# 1         1    784.442158  0.750034  05:37:48:442158
# 2         2    855.851676  0.625029  05:38:59:851676
# 3         3    903.306973  0.890666  05:39:47:306973
# 4         4   1019.765429  0.968794  05:41:43:765429
# ...     ...           ...       ...              ...
# 7668   7668  56772.036208  1.140677  21:10:56:036208
# 7669   7669  56879.759889  0.578151  21:12:43:759889
# 7670   7670  56973.451678  1.093800  21:14:17:451678
# 7671   7671  56974.623606  1.171929  21:14:18:623606
# 7672   7672  57098.519902  0.843789  21:16:22:519902
#
# [7673 rows x 4 columns]
